# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("adult.csv")
data_num = data.copy()

# %%
data.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
data['income']=data['income'].map({'<=50K': 0, '>50K': 1, '<=50K.': 0, '>50K.': 1})

# %% [markdown]
# 1.Show the summary statistics of all numerical variables.

# %%
data.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week        income
# count  48842.000000    48842.000000  48842.000000
# mean      87.502314       40.422382      0.239282
# std      403.004552       12.391444      0.426649
# min        0.000000        1.000000      0.000000
# 25%        0.000000       40.000000      0.000000
# 50%        0.000000       40.000000      0.000000
# ...

# %% [markdown]
# 2.Identify categorical and continuous variables.

# %% [markdown]
# Category Variable:
# 1.	Work class
# 2.	Marital-status
# 3.	Occupation
# 4.	Relationship
# 5.	Race
# 6.	Gender
# 7.	Native-country
# Continuous Variable:
# 1.	Age
# 2.	Final weight
# 3.	Education-number
# 4.	Capital-gain
# 5.	Capital-loss
# 6.	Hours-per-week
# 7.	income

# %%
data.hist(figsize=(10,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002DF347268D0>,
# ...
#       dtype=object)

# %% [markdown]
# 3.For each categorical variable, print frequency and relative frequency tables.
# 4.Draw bar plots for each categorical variable.

# %%
Table_workclass = data['workclass'].value_counts()
Table_workclass.plot(kind='barh')

# %%
Table_workclass
# Out:
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: workclass, dtype: int64

# %%
Table_workclass = data['workclass'].value_counts()/len(data['workclass'])
Table_workclass
# Out:
# Private             0.694198
# Self-emp-not-inc    0.079071
# Local-gov           0.064207
# ?                   0.057307
# State-gov           0.040559
# Self-emp-inc        0.034704
# Federal-gov         0.029319
# Without-pay         0.000430
# Never-worked        0.000205
# Name: workclass, dtype: float64

# %%
Table_maritalstatus = data['marital-status'].value_counts()
Table_maritalstatus.plot(kind='barh')

# %%
Table_maritalstatus
# Out:
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: marital-status, dtype: int64

# %%
Table_maritalstatus= data['marital-status'].value_counts()/len(data['marital-status'])
Table_maritalstatus
# Out:
# Married-civ-spouse       0.458192
# Never-married            0.329982
# Divorced                 0.135805
# Separated                0.031325
# Widowed                  0.031080
# Married-spouse-absent    0.012858
# Married-AF-spouse        0.000758
# Name: marital-status, dtype: float64

# %%
Table_occupation = data['occupation'].value_counts()
Table_occupation.plot(kind='barh')

# %%
Table_occupation
# Out:
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: occupation, dtype: int64

# %%
Table_occupation = data['occupation'].value_counts()/len(data['occupation'])
Table_occupation
# Out:
# Prof-specialty       0.126367
# Craft-repair         0.125138
# Exec-managerial      0.124606
# Adm-clerical         0.114881
# Sales                0.112690
# Other-service        0.100794
# Machine-op-inspct    0.061873
# ?                    0.057512
# Transport-moving     0.048217
# Handlers-cleaners    0.042423
# Farming-fishing      0.030507
# Tech-support         0.029606
# Protective-serv      0.020126
# Priv-house-serv      0.004955
# Armed-Forces         0.000307
# Name: occupation, dtype: float64

# %%
Table_relationship = data['relationship'].value_counts()
Table_relationship.plot(kind='barh')

# %%
Table_relationship
# Out:
# Husband           19716
# Not-in-family     12583
# Own-child          7581
# Unmarried          5125
# Wife               2331
# Other-relative     1506
# Name: relationship, dtype: int64

# %%
Table_relationship = data['relationship'].value_counts()/len(data['relationship'])
Table_relationship
# Out:
# Husband           0.403669
# Not-in-family     0.257627
# Own-child         0.155215
# Unmarried         0.104930
# Wife              0.047725
# Other-relative    0.030834
# Name: relationship, dtype: float64

# %%
Table_race = data['race'].value_counts()
Table_race.plot(kind='barh')

# %%
Table_race
# Out:
# White                 41762
# Black                  4685
# Asian-Pac-Islander     1519
# Amer-Indian-Eskimo      470
# Other                   406
# Name: race, dtype: int64

# %%
Table_race = data['race'].value_counts()/len(data['race'])
Table_race
# Out:
# White                 0.855043
# Black                 0.095922
# Asian-Pac-Islander    0.031100
# Amer-Indian-Eskimo    0.009623
# Other                 0.008313
# Name: race, dtype: float64

# %%
Table_gender = data['gender'].value_counts()
Table_gender.plot(kind='barh')

# %%
Table_gender
# Out:
# Male      32650
# Female    16192
# Name: gender, dtype: int64

# %%
Table_gender = data['gender'].value_counts()/len(data['gender'])
Table_gender
# Out:
# Male      0.668482
# Female    0.331518
# Name: gender, dtype: float64

# %%
Table_nativecountry = data['native-country'].value_counts()
Table_nativecountry.plot(kind='bar')

# %%
Table_nativecountry
# Out:
# United-States                 43832
# Mexico                          951
# ?                               857
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Nicaragua                        49
# ...

# %%
Table_nativecountry = data['native-country'].value_counts()/len(data['native-country'])
Table_nativecountry
# Out:
# United-States                 0.897424
# Mexico                        0.019471
# ?                             0.017546
# Philippines                   0.006040
# Germany                       0.004218
# Puerto-Rico                   0.003767
# Canada                        0.003726
# El-Salvador                   0.003173
# India                         0.003092
# Cuba                          0.002825
# England                       0.002600
# China                         0.002498
# South                         0.002355
# Jamaica                       0.002170
# Italy                         0.002150
# Dominican-Republic            0.002109
# Japan                         0.001884
# Guatemala                     0.001802
# Poland                        0.001781
# Vietnam                       0.001761
# Columbia                      0.001740
# Haiti                         0.001536
# Portugal                      0.001372
# Taiwan                        0.001331
# ...

# %% [markdown]
# 5.For each continuous variable, draw histograms and distribution plots.

# %%
sns.distplot(data['age'])

# %%
sns.distplot(data['fnlwgt'])

# %%
sns.distplot(data['educational-num'])

# %%
sns.distplot(data['capital-gain'])

# %%
sns.distplot(data['capital-loss'])

# %%
sns.distplot(data['hours-per-week'])

# %%
sns.distplot(data['income'])

# %% [markdown]
# 6.Draw pairwise scatterplots for continuous variables. Explain any discernable patterns?

# %%
sns.pairplot(data)

# %% [markdown]
# 1. Weight and work hours are decreasing as the term of age increasing.
# 2. Slender people(the value of fnlwgt is lower than 10000000) seems more interested in investment.
# 3. The level of education looked unrelated to the work hours and income.
# 4. The amount of people who have capital gain is less than the number of people who have a capital loss.

# %% [markdown]
# 7.Draw a heatm ap for the correlations among all variables. What do you observe?

# %%
corr = data.corr()
heat = sns.heatmap(corr)

# %% [markdown]
# 1. Each variable has a low relation to other variables.
# 2. Education numbers have a positive relationship to work hours and capital gain.
